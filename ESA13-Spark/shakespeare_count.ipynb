# %%
def cleanInput(lines):
    lines = lines.lower()
    lines = lines.replace("?", "")
    lines = lines.replace("!", "")
    lines = lines.replace(":", "")
    lines = lines.replace(".", "")
    lines = lines.replace(",", "")
    lines = lines.replace("[", "")
    lines = lines.replace("]", "")
    lines = lines.replace(";", "")
    lines = lines.replace("'", "")
    lines = lines.replace('"', "")
    lines = lines.split()
    return lines

lines = sc.textFile("t8.shakespeare.txt")
words = lines.flatMap(cleanInput)

wordCounts = words.countByValue()
sortedWordCounts = sorted(wordCounts.items(), key=lambda x: x[1], reverse=True)

for i in range(100):
    word, count = sortedWordCounts[i]
    print(f"{i+1}: {word} - {count} ")
# Out:
# 1: the - 27354
# 2: and - 26016
# 3: i - 20667
# 4: to - 19141
# 5: of - 17456
# 6: a - 14584
# 7: you - 13558
# 8: my - 12474
# 9: in - 10948
# 10: that - 10880
# 11: is - 9114
# 12: not - 8464
# 13: with - 7766
# 14: me - 7703
# 15: it - 7647
# 16: for - 7545
# 17: his - 6852
# 18: be - 6839
# 19: your - 6654
# 20: this - 6586
# 21: but - 6261
# 22: he - 6240
# 23: have - 5875
# 24: as - 5713
# 25: thou - 5479
# 26: him - 5157
# 27: so - 5023
# 28: will - 4964
# 29: what - 4455
# 30: thy - 4032
# 31: all - 3859
# 32: her - 3830
# 33: no - 3784
# 34: do - 3741
# 35: by - 3728
# 36: shall - 3585
# 37: if - 3487
# 38: are - 3398
# 39: we - 3296
# 40: thee - 3161
# 41: our - 3061
# 42: on - 3042
# 43: lord - 3011
# 44: king - 2849
# 45: good - 2810
# 46: now - 2761
# 47: sir - 2729
# 48: from - 2635
# 49: o - 2596
# 50: at - 2500
# 51: come - 2499
# 52: they - 2466
# 53: well - 2448
# 54: or - 2423
# 55: which - 2310
# 56: would - 2290
# 57: more - 2278
# 58: was - 2224
# 59: then - 2213
# 60: she - 2203
# 61: am - 2161
# 62: how - 2157
# 63: here - 2106
# 64: let - 2099
# 65: enter - 2098
# 66: their - 2074
# 67: when - 2049
# 68: love - 2033
# 69: ill - 1972
# 70: them - 1956
# 71: hath - 1940
# 72: than - 1879
# 73: an - 1832
# 74: man - 1822
# 75: there - 1800
# 76: one - 1770
# 77: upon - 1730
# 78: go - 1728
# 79: like - 1697
# 80: say - 1663
# 81: know - 1638
# 82: may - 1631
# 83: make - 1628
# 84: did - 1624
# 85: us - 1611
# 86: were - 1573
# 87: should - 1570
# 88: yet - 1560
# 89: must - 1490
# 90: why - 1461
# 91: see - 1429
# 92: had - 1427
# 93: tis - 1402
# 94: such - 1389
# 95: out - 1365
# 96: some - 1336
# 97: give - 1326
# 98: these - 1319
# 99: where - 1228
# 100: too - 1222

# %%
#Das 24. häufigste Wort ist "as".
